# %%
import os
import numpy as np
from PIL import Image
from sklearn.cluster import KMeans
from skimage import color, feature
from collections import Counter
from scipy.stats import skew, kurtosis
import cv2
import piexif
import json
import sys
import time

def is_similar(row, tolerance=10):
    """
    Check if all pixels in the row are similar within the given tolerance.
    """
    # Compute the difference between max and min for each channel
    diff = row.max(axis=0) - row.min(axis=0)
    return np.all(diff < tolerance)

def find_letterbox_height(image_np, tolerance=10, min_height=10, from_top=True):
    """
    Find the height of the letterbox from the top or bottom.
    """
    height, width, _ = image_np.shape
    letterbox_height = 0
    range_y = range(height) if from_top else range(height-1, -1, -1)
    
    for y in range_y:
        row = image_np[y, :, :]
        if is_similar(row, tolerance):
            letterbox_height +=1
        else:
            break
    # Ensure the detected letterbox is at least min_height pixels
    if letterbox_height >= min_height:
        return letterbox_height
    else:
        return 0

def remove_letterbox(image_np, tolerance=10, min_letterbox_height=10):
    """
    Detect and remove letterboxing from the top and bottom of the image.
    """
    top_height = find_letterbox_height(image_np, tolerance, min_letterbox_height, from_top=True)
    bottom_height = find_letterbox_height(image_np, tolerance, min_letterbox_height, from_top=False)
    
    # and if the absolute value of the difference between the top and bottom is less than min_height
    if (top_height > 0 or bottom_height > 0) and abs(top_height - bottom_height) < min_letterbox_height:
        cropped_image = image_np[top_height: image_np.shape[0] - bottom_height, :, :]
        print(f"Removed letterbox: Top={top_height}px, Bottom={bottom_height}px")
        return cropped_image
    else:
        print("No letterbox detected.")
        return image_np

def embed_metrics_into_exif(image_path, output_path, metrics_dict):
    """
    Embed the metrics dictionary into the JPEG's EXIF UserComment field.
    """
    try:
        # Load existing EXIF data
        exif_dict = piexif.load(image_path)
    except Exception as e:
        print(f"Error loading EXIF data for {image_path}: {e}")
        exif_dict = {"0th": {}, "Exif": {}, "GPS": {}, "1st": {}, "thumbnail": None}
    
    # Convert metrics dictionary to JSON string
    metrics_json = json.dumps(metrics_dict)
    
    # EXIF UserComment requires a specific format: a character code followed by the comment
    # We'll use ASCII encoding for simplicity
    user_comment = "ASCII\0\0\0" + metrics_json
    
    # Encode the comment to bytes
    user_comment_bytes = user_comment.encode('utf-8')
    
    # Insert the UserComment into EXIF
    exif_dict['Exif'][piexif.ExifIFD.UserComment] = user_comment_bytes
    
    # Dump the EXIF data to bytes
    exif_bytes = piexif.dump(exif_dict)
    
    # Save the image with new EXIF data
    try:
        image = Image.open(image_path)
        image.save(output_path, "jpeg", exif=exif_bytes)
        print(f"Saved image with embedded metrics to {output_path}")
    except Exception as e:
        print(f"Error saving image with EXIF data for {image_path}: {e}")

def get_all_image_paths(root_dir, supported_extensions=None):
    """
    Traverse the root_dir and return a list of all image file paths.
    """
    if supported_extensions is None:
        supported_extensions = ('.jpg', '.jpeg', '.png', '.tiff', '.bmp', '.gif')
    
    image_paths = []
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.lower().endswith(supported_extensions):
                image_paths.append(os.path.join(dirpath, filename))
    return image_paths

def has_user_comment(image_path):
    """
    Check if the image already has a UserComment in its EXIF data.
    """
    try:
        exif_dict = piexif.load(image_path)
        user_comment = exif_dict['Exif'].get(piexif.ExifIFD.UserComment, None)
        if user_comment:
            # Decode the UserComment
            try:
                # UserComment starts with a 8-byte code
                comment_str = user_comment.decode('utf-8', errors='ignore')
                # Remove the first 8 bytes (the encoding)
                comment_str = comment_str[8:]
                if comment_str.strip():
                    return True
            except:
                return False
        return False
    except:
        return False

def process_image(image_path):
    """
    Process a single image: remove letterbox, perform k-means clustering,
    compute metrics, and embed them into EXIF.
    Returns True if processed successfully, False otherwise.
    """
    outputImagePath = image_path  # Overwrite the original image

    try:
        image = Image.open(image_path)
    except FileNotFoundError:
        print(f"Image not found at path: {image_path}")
        return False
    except Exception as e:
        print(f"Error opening image {image_path}: {e}")
        return False

    image_np = np.array(image)

    # Ensure the image is in RGB format
    if image.mode != 'RGB':
        image = image.convert('RGB')
        image_np = np.array(image)

    # Remove alpha channel if present
    if image_np.shape[2] == 4:
        image_np = image_np[:, :, :3]

    # *** Detect and Remove Letterbox ***
    # Parameters can be adjusted based on the expected letterbox characteristics
    tolerance = 2              # Tolerance for color similarity (0-255)
    min_letterbox_height = 10  # Minimum height in pixels to consider as letterbox

    image_np = remove_letterbox(image_np, tolerance, min_letterbox_height)

    # Step 2: Normalize and convert to LAB color space
    image_normalized = image_np / 255.0
    image_lab = color.rgb2lab(image_normalized)

    # Step 3: Reshape image data for clustering
    pixels_lab = image_lab.reshape(-1, 3)

    # Step 4: Perform k-means clustering with k=8
    k = 8  # Set the number of clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pixels_lab)

    # Step 5: Process cluster centers
    cluster_centers_lab = kmeans.cluster_centers_
    cluster_centers_rgb = color.lab2rgb(cluster_centers_lab.reshape(1, -1, 3))
    cluster_centers_rgb = np.squeeze(cluster_centers_rgb)
    cluster_centers_rgb_uint8 = np.clip(cluster_centers_rgb * 255, 0, 255).astype(int)

    # Step 6: Quantify and visualize cluster sizes
    labels = kmeans.labels_
    counts = Counter(labels)
    total_pixels = sum(counts.values())

    # Sort clusters by the number of pixels
    sorted_counts = counts.most_common()
    sorted_cluster_indices = [item[0] for item in sorted_counts]
    sorted_cluster_sizes = [item[1] for item in sorted_counts]
    sorted_cluster_percentages = [(count / total_pixels) * 100 for count in sorted_cluster_sizes]
    sorted_colors_rgb = np.array([cluster_centers_rgb_uint8[i] for i in sorted_cluster_indices])

    # *** Removed Section: Variables related to bar charts ***
    # bar_colors = sorted_colors_rgb / 255
    # cluster_numbers = range(1, k + 1)
    # *** End of Removed Section ***

    # *** Compute Additional Image Metrics ***

    # Convert LAB to HSV for saturation metrics
    image_hsv = color.rgb2hsv(image_normalized)
    saturation = image_hsv[:, :, 1]
    mean_saturation = np.mean(saturation)
    median_saturation = np.median(saturation)
    std_saturation = np.std(saturation)

    # Luminance Metrics
    l_channel = image_lab[:, :, 0]
    mean_luminance = np.mean(l_channel)
    median_luminance = np.median(l_channel)
    std_luminance = np.std(l_channel)
    dynamic_range = l_channel.max() - l_channel.min()

    # Contrast Metrics
    rms_contrast = np.sqrt(np.mean(l_channel**2))
    michelson_contrast = (l_channel.max() - l_channel.min()) / (l_channel.max() + l_channel.min())

    # Texture Features using GLCM
    glcm = feature.graycomatrix(l_channel.astype(np.uint8), distances=[5], angles=[0], levels=256, symmetric=True, normed=True)
    glcm_contrast = feature.graycoprops(glcm, 'contrast')[0, 0]
    glcm_correlation = feature.graycoprops(glcm, 'correlation')[0, 0]

    # Sharpness using Variance of Laplacian
    laplacian_var = cv2.Laplacian(l_channel, cv2.CV_64F).var()

    # Skewness and Kurtosis of Luminance
    lum_skew = skew(l_channel.flatten())
    lum_kurt = kurtosis(l_channel.flatten())

    # Compile Features
    # additional_features = {
    #     'Mean Luminance': f"{mean_luminance:.2f}",
    #     'Median Luminance': f"{median_luminance:.2f}",
    #     'Std Luminance': f"{std_luminance:.2f}",
    #     'Dynamic Range': f"{dynamic_range:.2f}",
    #     'RMS Contrast': f"{rms_contrast:.2f}",
    #     'Michelson Contrast': f"{michelson_contrast:.2f}",
    #     'Mean Saturation': f"{mean_saturation:.2f}",
    #     'Median Saturation': f"{median_saturation:.2f}",
    #     'Std Saturation': f"{std_saturation:.2f}",
    #     'GLCM Contrast': f"{glcm_contrast:.2f}",
    #     'GLCM Correlation': f"{glcm_correlation:.2f}",
    #     'Laplacian Variance': f"{laplacian_var:.2f}",
    #     'Luminance Skewness': f"{lum_skew:.2f}",
    #     'Luminance Kurtosis': f"{lum_kurt:.2f}"
    # }

    # *** Compile K-Means Clustering Results ***
    # clustering_results = {
    #     'KMeans Clustering': {
    #         'Number of Clusters': k,
    #         'Cluster Centers (RGB)': cluster_centers_rgb_uint8.tolist(),
    #         'Cluster Counts': sorted_cluster_sizes,
    #         'Cluster Percentages': [f"{pct:.2f}%" for pct in sorted_cluster_percentages]
    #     }
    # }

    # *** Combine All Metrics ***
    all_metrics = {
          'Mean Luminance': f"{mean_luminance:.2f}",
        'Median Luminance': f"{median_luminance:.2f}",
        'Std Luminance': f"{std_luminance:.2f}",
        'Dynamic Range': f"{dynamic_range:.2f}",
        'RMS Contrast': f"{rms_contrast:.2f}",
        'Michelson Contrast': f"{michelson_contrast:.2f}",
        'Mean Saturation': f"{mean_saturation:.2f}",
        'Median Saturation': f"{median_saturation:.2f}",
        'Std Saturation': f"{std_saturation:.2f}",
        'GLCM Contrast': f"{glcm_contrast:.2f}",
        'GLCM Correlation': f"{glcm_correlation:.2f}",
        'Laplacian Variance': f"{laplacian_var:.2f}",
        'Luminance Skewness': f"{lum_skew:.2f}",
        'Luminance Kurtosis': f"{lum_kurt:.2f}",
        'KMeans Clustering': {
            'Number of Clusters': k,
            'Cluster Centers (RGB)': cluster_centers_rgb_uint8.tolist(),
            'Cluster Counts': sorted_cluster_sizes,
            'Cluster Percentages': [f"{pct:.2f}%" for pct in sorted_cluster_percentages]
        }
    }

    # *** Embed Metrics into EXIF Metadata ***
    embed_metrics_into_exif(image_path=image_path, output_path=outputImagePath, metrics_dict=all_metrics)

    return True

def main():
    # Define the root images directory
    root_images_dir = "/Users/greyson/Projects/custom_gallery/gallery/public/img/"

    # Get all image file paths
    print("Collecting image files...")
    image_paths = get_all_image_paths(root_images_dir)
    total_images = len(image_paths)
    print(f"Found {total_images} image(s) to process.")

    if total_images == 0:
        print("No images found. Exiting.")
        sys.exit(0)

    # Initialize counters and timers
    processed_count = 0
    skipped_count = 0
    start_time = time.time()

    for idx, image_path in enumerate(image_paths, start=1):
        print(f"\nProcessing image {idx}/{total_images}: {image_path}")

        # if has_user_comment(image_path):
        #     print("Image already has EXIF UserComment. Skipping.")
        #     skipped_count += 1
        #     continue

        image_start_time = time.time()
        success = process_image(image_path)
        image_end_time = time.time()

        if success:
            processed_count += 1
            print(f"Processed in {image_end_time - image_start_time:.2f} seconds.")
        else:
            print("Failed to process this image.")

        # Calculate elapsed time and estimate remaining time
        elapsed_time = time.time() - start_time
        avg_time_per_image = elapsed_time / idx
        remaining_images = total_images - idx
        estimated_remaining_time = avg_time_per_image * remaining_images

        # Format estimated remaining time
        hrs, rem = divmod(estimated_remaining_time, 3600)
        mins, secs = divmod(rem, 60)
        time_str = ""
        if hrs >= 1:
            time_str += f"{int(hrs)}h "
        if mins >= 1:
            time_str += f"{int(mins)}m "
        time_str += f"{int(secs)}s"

        print(f"Estimated time remaining: {time_str}")

    total_elapsed = time.time() - start_time
    hrs, rem = divmod(total_elapsed, 3600)
    mins, secs = divmod(rem, 60)
    total_time_str = ""
    if hrs >= 1:
        total_time_str += f"{int(hrs)}h "
    if mins >= 1:
        total_time_str += f"{int(mins)}m "
    total_time_str += f"{int(secs)}s"

    print("\nProcessing Complete!")
    print(f"Total images processed: {processed_count}")
    print(f"Total images skipped: {skipped_count}")
    print(f"Total time taken: {total_time_str}")

if __name__ == "__main__":
    # Ensure piexif is installed. If not, provide instructions.
    try:
        import piexif
    except ImportError:
        print("The 'piexif' library is required to embed metadata. Install it using 'pip install piexif'.")
        sys.exit(1)

    main()
# Out:
# Collecting image files...
# Found 1844 image(s) to process.
#
# Processing image 1/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330257550_869215664158675_3796246925761316888_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330257550_869215664158675_3796246925761316888_n.jpg
# Processed in 0.95 seconds.
# Estimated time remaining: 29m 8s
#
# Processing image 2/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330655364_215130921052217_1176247351636244488_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330655364_215130921052217_1176247351636244488_n.jpg
# Processed in 0.89 seconds.
# Estimated time remaining: 28m 10s
#
# Processing image 3/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330460771_199998375946354_2662414262611942590_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330460771_199998375946354_2662414262611942590_n.jpg
# Processed in 0.91 seconds.
# Estimated time remaining: 28m 6s
#
# Processing image 4/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330862592_904912890706381_4592382367764822310_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330862592_904912890706381_4592382367764822310_n.jpg
# Processed in 1.03 seconds.
# Estimated time remaining: 28m 59s
#
# Processing image 5/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330860189_171110682331632_1618914992195157424_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330860189_171110682331632_1618914992195157424_n.jpg
# Processed in 0.94 seconds.
# Estimated time remaining: 28m 58s
#
# Processing image 6/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330382332_645233037408550_6227451029580514360_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330382332_645233037408550_6227451029580514360_n.jpg
# Processed in 0.87 seconds.
# Estimated time remaining: 28m 35s
#
# Processing image 7/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330622344_1333210050555336_5650301651384983299_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330622344_1333210050555336_5650301651384983299_n.jpg
# Processed in 0.84 seconds.
# Estimated time remaining: 28m 10s
#
# Processing image 8/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330478567_2071721843219138_2781159854680345691_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330478567_2071721843219138_2781159854680345691_n.jpg
# Processed in 0.91 seconds.
# Estimated time remaining: 28m 7s
#
# Processing image 9/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330452919_495515506082828_6928323655948451005_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330452919_495515506082828_6928323655948451005_n.jpg
# Processed in 0.91 seconds.
# Estimated time remaining: 28m 4s
#
# Processing image 10/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330652951_609248804545496_3143547228365390646_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-02-13_17-37-29_ConHictJyXu/330652951_609248804545496_3143547228365390646_n.jpg
# Processed in 0.85 seconds.
# Estimated time remaining: 27m 50s
#
# Processing image 11/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409820103_18403863199048990_5059239316965373593_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409820103_18403863199048990_5059239316965373593_n.jpg
# Processed in 0.89 seconds.
# Estimated time remaining: 27m 47s
#
# Processing image 12/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409617217_18403863190048990_6029114216769775984_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409617217_18403863190048990_6029114216769775984_n.jpg
# Processed in 1.09 seconds.
# Estimated time remaining: 28m 13s
#
# Processing image 13/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409891223_18403863163048990_2640569901227969281_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409891223_18403863163048990_2640569901227969281_n.jpg
# Processed in 0.98 seconds.
# Estimated time remaining: 28m 20s
#
# Processing image 14/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409677935_18403863217048990_6295431528357698644_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409677935_18403863217048990_6295431528357698644_n.jpg
# Processed in 0.98 seconds.
# Estimated time remaining: 28m 25s
#
# Processing image 15/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409716045_18403863181048990_4621429633639622285_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409716045_18403863181048990_4621429633639622285_n.jpg
# Processed in 0.92 seconds.
# Estimated time remaining: 28m 23s
#
# Processing image 16/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409733543_18403863208048990_4408523992234298765_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409733543_18403863208048990_4408523992234298765_n.jpg
# Processed in 1.16 seconds.
# Estimated time remaining: 28m 49s
#
# Processing image 17/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409587919_18403863172048990_3381092323836652340_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-12_18-17-23_C0w0K3rvmhk/409587919_18403863172048990_3381092323836652340_n.jpg
# Processed in 0.92 seconds.
# Estimated time remaining: 28m 45s
#
# Processing image 18/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299309755_435013411997824_3887054144747333402_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299309755_435013411997824_3887054144747333402_n.jpg
# Processed in 1.47 seconds.
# Estimated time remaining: 29m 37s
#
# Processing image 19/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299174706_1097236380898302_8170588517886631607_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299174706_1097236380898302_8170588517886631607_n.jpg
# Processed in 1.37 seconds.
# Estimated time remaining: 30m 14s
#
# Processing image 20/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299388673_8026610157412955_4484546087704344896_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299388673_8026610157412955_4484546087704344896_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 30m 25s
#
# Processing image 21/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299447909_576932817444873_7407305050534917923_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299447909_576932817444873_7407305050534917923_n.jpg
# Processed in 1.34 seconds.
# Estimated time remaining: 30m 53s
#
# Processing image 22/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299477304_793445105005219_7301225544194424245_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299477304_793445105005219_7301225544194424245_n.jpg
# Processed in 1.51 seconds.
# Estimated time remaining: 31m 33s
#
# Processing image 23/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299993971_175934484941350_1655601837822426268_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299993971_175934484941350_1655601837822426268_n.jpg
# Processed in 1.55 seconds.
# Estimated time remaining: 32m 12s
#
# Processing image 24/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299616951_787611185924569_2450305491368932232_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-15_15-26-17_ChSP2OVL2bn/299616951_787611185924569_2450305491368932232_n.jpg
# Processed in 1.13 seconds.
# Estimated time remaining: 32m 16s
#
# Processing image 25/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335927296_1376627923103099_7977624241063130814_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335927296_1376627923103099_7977624241063130814_n.jpg
# Processed in 1.06 seconds.
# Estimated time remaining: 32m 15s
#
# Processing image 26/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336105421_525919992802599_2803329394145899256_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336105421_525919992802599_2803329394145899256_n.jpg
# Processed in 1.04 seconds.
# Estimated time remaining: 32m 13s
#
# Processing image 27/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336030793_176101701877799_5422624925142329866_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336030793_176101701877799_5422624925142329866_n.jpg
# Processed in 0.97 seconds.
# Estimated time remaining: 32m 5s
#
# Processing image 28/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336516313_230625866019650_6246335549759300295_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336516313_230625866019650_6246335549759300295_n.jpg
# Processed in 1.84 seconds.
# Estimated time remaining: 32m 55s
#
# Processing image 29/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335921299_609209434579394_6815690867667973264_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335921299_609209434579394_6815690867667973264_n.jpg
# Processed in 1.11 seconds.
# Estimated time remaining: 32m 55s
#
# Processing image 30/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336051122_958772271947865_5068079604312739686_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336051122_958772271947865_5068079604312739686_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 32m 56s
#
# Processing image 31/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336235212_539323071664834_6428925055007589496_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336235212_539323071664834_6428925055007589496_n.jpg
# Processed in 1.04 seconds.
# Estimated time remaining: 32m 52s
#
# Processing image 32/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335776806_537322465136150_7994652258665143254_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/335776806_537322465136150_7994652258665143254_n.jpg
# Processed in 1.01 seconds.
# Estimated time remaining: 32m 47s
#
# Processing image 33/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336005114_728251448757983_171875248993861888_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-03-17_16-13-47_Cp5XZXbrDMr/336005114_728251448757983_171875248993861888_n.jpg
# Processed in 1.41 seconds.
# Estimated time remaining: 33m 4s
#
# Processing image 34/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273646037_3046056825633678_579205272323769778_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273646037_3046056825633678_579205272323769778_n.jpg
# Processed in 0.65 seconds.
# Estimated time remaining: 32m 38s
#
# Processing image 35/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273662599_347448803853948_3459062928860113010_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273662599_347448803853948_3459062928860113010_n.jpg
# Processed in 0.86 seconds.
# Estimated time remaining: 32m 26s
#
# Processing image 36/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273590517_614232786314541_1826757127026712077_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273590517_614232786314541_1826757127026712077_n.jpg
# Processed in 0.76 seconds.
# Estimated time remaining: 32m 9s
#
# Processing image 37/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273688286_1436664330063866_578781878266693069_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273688286_1436664330063866_578781878266693069_n.jpg
# Processed in 0.76 seconds.
# Estimated time remaining: 31m 52s
#
# Processing image 38/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273699761_516702163118229_5516136287032695980_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273699761_516702163118229_5516136287032695980_n.jpg
# Processed in 0.89 seconds.
# Estimated time remaining: 31m 43s
#
# Processing image 39/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273731006_300044055526248_4560474952682161599_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273731006_300044055526248_4560474952682161599_n.jpg
# Processed in 0.78 seconds.
# Estimated time remaining: 31m 30s
#
# Processing image 40/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273757107_695476754777663_7182439985112687334_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273757107_695476754777663_7182439985112687334_n.jpg
# Processed in 0.86 seconds.
# Estimated time remaining: 31m 20s
#
# Processing image 41/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273749637_1275318832934903_1099951678866898961_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273749637_1275318832934903_1099951678866898961_n.jpg
# Processed in 0.73 seconds.
# Estimated time remaining: 31m 5s
#
# Processing image 42/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273702439_122387966991185_2921712682064892972_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-10_18-55-40_CZzr9Envmtn/273702439_122387966991185_2921712682064892972_n.jpg
# Processed in 0.75 seconds.
# Estimated time remaining: 30m 52s
#
# Processing image 43/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314651585_204758245265261_8081429937743968672_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314651585_204758245265261_8081429937743968672_n.jpg
# Processed in 1.69 seconds.
# Estimated time remaining: 31m 19s
#
# Processing image 44/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314653654_518143703581568_1231955568943684230_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314653654_518143703581568_1231955568943684230_n.jpg
# Processed in 1.37 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 45/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314603816_5590271364341317_32301600371093485_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314603816_5590271364341317_32301600371093485_n.jpg
# Processed in 1.29 seconds.
# Estimated time remaining: 31m 39s
#
# Processing image 46/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314606719_895891351318154_3348700919240056195_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314606719_895891351318154_3348700919240056195_n.jpg
# Processed in 1.09 seconds.
# Estimated time remaining: 31m 40s
#
# Processing image 47/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314716486_149456817801954_5612624174732606542_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314716486_149456817801954_5612624174732606542_n.jpg
# Processed in 1.04 seconds.
# Estimated time remaining: 31m 38s
#
# Processing image 48/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314495517_3290002917919854_7379916807201573070_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314495517_3290002917919854_7379916807201573070_n.jpg
# Processed in 1.02 seconds.
# Estimated time remaining: 31m 36s
#
# Processing image 49/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314956021_172970008659882_1228807025338716625_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314956021_172970008659882_1228807025338716625_n.jpg
# Processed in 1.03 seconds.
# Estimated time remaining: 31m 34s
#
# Processing image 50/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314709413_694675598516192_5224720518314690428_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314709413_694675598516192_5224720518314690428_n.jpg
# Processed in 2.19 seconds.
# Estimated time remaining: 32m 13s
#
# Processing image 51/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314917524_167463415963017_9061991378744188766_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314917524_167463415963017_9061991378744188766_n.jpg
# Processed in 1.14 seconds.
# Estimated time remaining: 32m 14s
#
# Processing image 52/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314803208_803000844101911_8276942393077793429_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-11-09_16-30-00_CkvzgwKvze5/314803208_803000844101911_8276942393077793429_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 32m 15s
#
# Processing image 53/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409817639_18404211019048990_2064557516349281062_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409817639_18404211019048990_2064557516349281062_n.jpg
# Processed in 0.98 seconds.
# Estimated time remaining: 32m 10s
#
# Processing image 54/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409838489_18404211034048990_170021686893601899_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409838489_18404211034048990_170021686893601899_n.jpg
# Processed in 0.97 seconds.
# Estimated time remaining: 32m 5s
#
# Processing image 55/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409876061_18404210992048990_7723584525392296532_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409876061_18404210992048990_7723584525392296532_n.jpg
# Processed in 0.95 seconds.
# Estimated time remaining: 32m 0s
#
# Processing image 56/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409868292_18404210956048990_2901700665226180767_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409868292_18404210956048990_2901700665226180767_n.jpg
# Processed in 1.05 seconds.
# Estimated time remaining: 31m 58s
#
# Processing image 57/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409827239_18404210974048990_6745919793202955503_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409827239_18404210974048990_6745919793202955503_n.jpg
# Processed in 0.98 seconds.
# Estimated time remaining: 31m 55s
#
# Processing image 58/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409780566_18404211037048990_8831168014138791958_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409780566_18404211037048990_8831168014138791958_n.jpg
# Processed in 1.38 seconds.
# Estimated time remaining: 32m 3s
#
# Processing image 59/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/411208140_18404211010048990_8805255438373050114_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/411208140_18404211010048990_8805255438373050114_n.jpg
# Processed in 1.44 seconds.
# Estimated time remaining: 32m 13s
#
# Processing image 60/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409712974_18404210983048990_5344628928358677480_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409712974_18404210983048990_5344628928358677480_n.jpg
# Processed in 1.14 seconds.
# Estimated time remaining: 32m 13s
#
# Processing image 61/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409850947_18404211001048990_8910063163075984200_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/409850947_18404211001048990_8910063163075984200_n.jpg
# Processed in 1.00 seconds.
# Estimated time remaining: 32m 10s
#
# Processing image 62/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/411218225_18404210965048990_3363627587049539826_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-12-14_17-00-18_C0108HYvXg7/411218225_18404210965048990_3363627587049539826_n.jpg
# Processed in 0.93 seconds.
# Estimated time remaining: 32m 4s
#
# Processing image 63/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301148296_151987644174525_6208334776828554518_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301148296_151987644174525_6208334776828554518_n.jpg
# Processed in 1.00 seconds.
# Estimated time remaining: 32m 1s
#
# Processing image 64/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300788249_1438161123348419_8138131784381706099_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300788249_1438161123348419_8138131784381706099_n.jpg
# Processed in 0.98 seconds.
# Estimated time remaining: 31m 57s
#
# Processing image 65/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301386778_1504988326630704_3359516726437481029_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301386778_1504988326630704_3359516726437481029_n.jpg
# Processed in 1.03 seconds.
# Estimated time remaining: 31m 55s
#
# Processing image 66/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300938862_483670670267929_1467033967104196048_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300938862_483670670267929_1467033967104196048_n.jpg
# Processed in 0.95 seconds.
# Estimated time remaining: 31m 50s
#
# Processing image 67/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300971759_1228191191362517_4057306281901322473_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300971759_1228191191362517_4057306281901322473_n.jpg
# Processed in 0.96 seconds.
# Estimated time remaining: 31m 46s
#
# Processing image 68/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300943878_789285535829713_4037206028445924075_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300943878_789285535829713_4037206028445924075_n.jpg
# Processed in 0.72 seconds.
# Estimated time remaining: 31m 36s
#
# Processing image 69/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300830330_1094374014813003_5844912810231609234_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300830330_1094374014813003_5844912810231609234_n.jpg
# Processed in 1.24 seconds.
# Estimated time remaining: 31m 39s
#
# Processing image 70/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300696523_125197213591247_3909581930836475045_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300696523_125197213591247_3909581930836475045_n.jpg
# Processed in 1.09 seconds.
# Estimated time remaining: 31m 39s
#
# Processing image 71/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301167103_3332093550358943_269460354220402784_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/301167103_3332093550358943_269460354220402784_n.jpg
# Processed in 0.93 seconds.
# Estimated time remaining: 31m 34s
#
# Processing image 72/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300727588_796362821551937_8233846393705759624_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-08-24_15-09-23_ChpZEUeO8ds/300727588_796362821551937_8233846393705759624_n.jpg
# Processed in 0.96 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 73/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274842361_1109909096436655_3764003368479108597_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274842361_1109909096436655_3764003368479108597_n.jpg
# Processed in 1.07 seconds.
# Estimated time remaining: 31m 30s
#
# Processing image 74/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274649361_635191791121370_5634523554876565406_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274649361_635191791121370_5634523554876565406_n.jpg
# Processed in 1.24 seconds.
# Estimated time remaining: 31m 33s
#
# Processing image 75/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274542939_995003824726070_1068480357096120898_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274542939_995003824726070_1068480357096120898_n.jpg
# Processed in 1.03 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 76/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274647750_656081892114226_3332056922027728370_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274647750_656081892114226_3332056922027728370_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 77/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274612401_487519836368955_2376472142198880169_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274612401_487519836368955_2376472142198880169_n.jpg
# Processed in 1.22 seconds.
# Estimated time remaining: 31m 33s
#
# Processing image 78/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274633118_337742764921437_104057616010653831_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274633118_337742764921437_104057616010653831_n.jpg
# Processed in 1.04 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 79/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274687442_681543523150925_1179423775561431217_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274687442_681543523150925_1179423775561431217_n.jpg
# Processed in 1.11 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 80/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274685825_165225482512205_7556579409555328660_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274685825_165225482512205_7556579409555328660_n.jpg
# Processed in 1.01 seconds.
# Estimated time remaining: 31m 28s
#
# Processing image 81/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274638192_636748230749520_3512167512804172845_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274638192_636748230749520_3512167512804172845_n.jpg
# Processed in 1.22 seconds.
# Estimated time remaining: 31m 31s
#
# Processing image 82/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274634299_234037935602391_3909585741313720615_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-02-25_19-38-35_CaaYydavmhL/274634299_234037935602391_3909585741313720615_n.jpg
# Processed in 1.00 seconds.
# Estimated time remaining: 31m 28s
#
# Processing image 83/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448094018_1510325386552998_5998619971152247654_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448094018_1510325386552998_5998619971152247654_n.jpg
# Processed in 0.66 seconds.
# Estimated time remaining: 31m 18s
#
# Processing image 84/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448092127_983381363387791_710896650213185841_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448092127_983381363387791_710896650213185841_n.jpg
# Processed in 0.67 seconds.
# Estimated time remaining: 31m 9s
#
# Processing image 85/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448118904_1193072585376872_6350748174606901664_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448118904_1193072585376872_6350748174606901664_n.jpg
# Processed in 0.71 seconds.
# Estimated time remaining: 31m 0s
#
# Processing image 86/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448183014_446237868301012_7276853281885316110_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448183014_446237868301012_7276853281885316110_n.jpg
# Processed in 0.69 seconds.
# Estimated time remaining: 30m 52s
#
# Processing image 87/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448177427_6258009724323747_3928451947450295858_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2024-06-11_16-34-35_C8FRFReJ1yL/448177427_6258009724323747_3928451947450295858_n.jpg
# Processed in 0.69 seconds.
# Estimated time remaining: 30m 43s
#
# Processing image 88/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249817602_206972824843492_7070352212341480545_n.jpg
# Removed letterbox: Top=216px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249817602_206972824843492_7070352212341480545_n.jpg
# Processed in 1.20 seconds.
# Estimated time remaining: 30m 45s
#
# Processing image 89/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249843577_317896993000983_28387500273800029_n.jpg
# Removed letterbox: Top=207px, Bottom=208px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249843577_317896993000983_28387500273800029_n.jpg
# Processed in 1.14 seconds.
# Estimated time remaining: 30m 46s
#
# Processing image 90/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248991156_3044460522482627_2305511856726260347_n.jpg
# Removed letterbox: Top=207px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248991156_3044460522482627_2305511856726260347_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 30m 46s
#
# Processing image 91/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249036825_890186491694067_6900121880581021928_n.jpg
# Removed letterbox: Top=207px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249036825_890186491694067_6900121880581021928_n.jpg
# Processed in 1.06 seconds.
# Estimated time remaining: 30m 45s
#
# Processing image 92/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248974578_1263566684145964_6594014599154604313_n.jpg
# Removed letterbox: Top=216px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248974578_1263566684145964_6594014599154604313_n.jpg
# Processed in 1.14 seconds.
# Estimated time remaining: 30m 46s
#
# Processing image 93/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249308116_618597666001189_3028062597103224360_n.jpg
# Removed letterbox: Top=207px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249308116_618597666001189_3028062597103224360_n.jpg
# Processed in 1.16 seconds.
# Estimated time remaining: 30m 47s
#
# Processing image 94/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249118238_1227182007708216_1227718993560690915_n.jpg
# Removed letterbox: Top=207px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/249118238_1227182007708216_1227718993560690915_n.jpg
# Processed in 1.10 seconds.
# Estimated time remaining: 30m 47s
#
# Processing image 95/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248920878_430862935227542_1266449207593574919_n.jpg
# Removed letterbox: Top=207px, Bottom=207px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-10-27_22-57-58_CVjLa7oPeqe/248920878_430862935227542_1266449207593574919_n.jpg
# Processed in 1.17 seconds.
# Estimated time remaining: 30m 48s
#
# Processing image 96/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272753349_4661360233932794_8291997209797374354_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272753349_4661360233932794_8291997209797374354_n.jpg
# Processed in 0.54 seconds.
# Estimated time remaining: 30m 37s
#
# Processing image 97/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/273051966_155117436868335_5969572873127591762_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/273051966_155117436868335_5969572873127591762_n.jpg
# Processed in 0.61 seconds.
# Estimated time remaining: 30m 29s
#
# Processing image 98/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272901312_1012668809323012_4976234601552355923_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272901312_1012668809323012_4976234601552355923_n.jpg
# Processed in 0.61 seconds.
# Estimated time remaining: 30m 20s
#
# Processing image 99/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272954989_430861022161725_1966950451215509703_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272954989_430861022161725_1966950451215509703_n.jpg
# Processed in 0.64 seconds.
# Estimated time remaining: 30m 11s
#
# Processing image 100/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272742768_258189923080491_8458945273540560582_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272742768_258189923080491_8458945273540560582_n.jpg
# Processed in 0.56 seconds.
# Estimated time remaining: 30m 2s
#
# Processing image 101/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272840802_142059988229313_5637982237587773129_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272840802_142059988229313_5637982237587773129_n.jpg
# Processed in 0.67 seconds.
# Estimated time remaining: 29m 55s
#
# Processing image 102/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272698354_936071550606830_5198748535832609361_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272698354_936071550606830_5198748535832609361_n.jpg
# Processed in 0.67 seconds.
# Estimated time remaining: 29m 48s
#
# Processing image 103/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2022-01-28_17-29-15_CZSDuz6JKw2/272753117_462142372230132_1257140161194914359_n.jpg
# No letterbox detected.
# ...
# Estimated time remaining: 23m 7s
#
# Processing image 474/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-11-04_22-18-46_CV3tS2QPr6J/253625804_463957018390830_2119896276507583678_n.jpg
# Removed letterbox: Top=303px, Bottom=303px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-11-04_22-18-46_CV3tS2QPr6J/253625804_463957018390830_2119896276507583678_n.jpg
# Processed in 0.96 seconds.
# Estimated time remaining: 23m 6s
#
# Processing image 475/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402115392_18398624887048990_3568744094462270921_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402115392_18398624887048990_3568744094462270921_n.jpg
# Processed in 1.36 seconds.
# Estimated time remaining: 23m 6s
#
# Processing image 476/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402263671_18398624857048990_8425998249149684241_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402263671_18398624857048990_8425998249149684241_n.jpg
# Processed in 1.25 seconds.
# Estimated time remaining: 23m 6s
#
# Processing image 477/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402458645_18398624824048990_8965331868333901055_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402458645_18398624824048990_8965331868333901055_n.jpg
# Processed in 1.40 seconds.
# Estimated time remaining: 23m 6s
#
# Processing image 478/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402163375_18398624848048990_3784129691754973741_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402163375_18398624848048990_3784129691754973741_n.jpg
# Processed in 1.26 seconds.
# Estimated time remaining: 23m 5s
#
# Processing image 479/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402353549_18398624815048990_1494270580155527543_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402353549_18398624815048990_1494270580155527543_n.jpg
# Processed in 1.20 seconds.
# Estimated time remaining: 23m 5s
#
# Processing image 480/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/400086080_18398624866048990_7161581379388272525_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/400086080_18398624866048990_7161581379388272525_n.jpg
# Processed in 1.33 seconds.
# Estimated time remaining: 23m 5s
#
# Processing image 481/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/401458594_18398624791048990_6901623349322637128_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/401458594_18398624791048990_6901623349322637128_n.jpg
# Processed in 1.09 seconds.
# Estimated time remaining: 23m 4s
#
# Processing image 482/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402426471_18398624806048990_3402408554138588030_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402426471_18398624806048990_3402408554138588030_n.jpg
# Processed in 1.02 seconds.
# Estimated time remaining: 23m 3s
#
# Processing image 483/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402122101_18398624833048990_148176456988914949_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402122101_18398624833048990_148176456988914949_n.jpg
# Processed in 1.16 seconds.
# Estimated time remaining: 23m 2s
#
# Processing image 484/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402179716_18398624875048990_2105792683775426765_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2023-11-15_17-18-56_CzrMBMnvJfS/402179716_18398624875048990_2105792683775426765_n.jpg
# Processed in 1.07 seconds.
# Estimated time remaining: 23m 1s
#
# Processing image 485/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/268129823_433744118200942_1225094860038637167_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/268129823_433744118200942_1225094860038637167_n.jpg
# Processed in 1.22 seconds.
# Estimated time remaining: 23m 1s
#
# Processing image 486/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267016761_4738636129549727_5396537252359942810_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267016761_4738636129549727_5396537252359942810_n.jpg
# Processed in 1.03 seconds.
# Estimated time remaining: 23m 0s
#
# Processing image 487/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266746686_294971659225591_8710157413747569762_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266746686_294971659225591_8710157413747569762_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 22m 59s
#
# Processing image 488/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267658280_439100264470385_8394312296590944581_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267658280_439100264470385_8394312296590944581_n.jpg
# Processed in 1.21 seconds.
# Estimated time remaining: 22m 59s
#
# Processing image 489/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266555407_444992603859682_115515310418092284_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266555407_444992603859682_115515310418092284_n.jpg
# Processed in 1.45 seconds.
# Estimated time remaining: 22m 59s
#
# Processing image 490/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267528057_2952171891762674_6708458415239941072_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267528057_2952171891762674_6708458415239941072_n.jpg
# Processed in 1.23 seconds.
# Estimated time remaining: 22m 59s
#
# Processing image 491/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266778331_4776159739110014_9006988592515299441_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/266778331_4776159739110014_9006988592515299441_n.jpg
# Processed in 1.20 seconds.
# Estimated time remaining: 22m 58s
#
# Processing image 492/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267412480_899171494125420_95478128257015076_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267412480_899171494125420_95478128257015076_n.jpg
# Processed in 1.12 seconds.
# Estimated time remaining: 22m 57s
#
# Processing image 493/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267195724_3036118143343464_7728039786855065589_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267195724_3036118143343464_7728039786855065589_n.jpg
# Processed in 1.14 seconds.
# Estimated time remaining: 22m 57s
#
# Processing image 494/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267394955_874196276555130_68512575977964590_n.jpg
# No letterbox detected.
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-12-14_18-07-36_CXeQWN3P9GS/267394955_874196276555130_68512575977964590_n.jpg
# Processed in 1.27 seconds.
# Estimated time remaining: 22m 56s
#
# Processing image 495/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241452322_527145798581840_6241402984279993301_n.jpg
# Removed letterbox: Top=223px, Bottom=232px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241452322_527145798581840_6241402984279993301_n.jpg
# Processed in 0.75 seconds.
# Estimated time remaining: 22m 55s
#
# Processing image 496/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241268527_569947651108134_7546714322656987992_n.jpg
# Removed letterbox: Top=223px, Bottom=231px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241268527_569947651108134_7546714322656987992_n.jpg
# Processed in 0.71 seconds.
# Estimated time remaining: 22m 53s
#
# Processing image 497/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241313878_248839287108180_4256420154336870331_n.jpg
# Removed letterbox: Top=223px, Bottom=231px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241313878_248839287108180_4256420154336870331_n.jpg
# Processed in 0.65 seconds.
# Estimated time remaining: 22m 51s
#
# Processing image 498/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241315689_2874421246155337_7136648731332389065_n.jpg
# Removed letterbox: Top=223px, Bottom=231px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241315689_2874421246155337_7136648731332389065_n.jpg
# Processed in 0.82 seconds.
# Estimated time remaining: 22m 49s
#
# Processing image 499/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241314431_891116894839850_1095683193567729537_n.jpg
# Removed letterbox: Top=223px, Bottom=231px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241314431_891116894839850_1095683193567729537_n.jpg
# Processed in 0.70 seconds.
# Estimated time remaining: 22m 47s
#
# Processing image 500/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241325003_1856073617912068_4111174308329506936_n.jpg
# Removed letterbox: Top=223px, Bottom=231px
# Saved image with embedded metrics to /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241325003_1856073617912068_4111174308329506936_n.jpg
# Processed in 0.69 seconds.
# Estimated time remaining: 22m 45s
#
# Processing image 501/1844: /Users/greyson/Projects/custom_gallery/gallery/public/img/cameronmarygold/2021-09-06_16-14-13_CTfIrOzlkzb/241314192_211946040976352_5877938866502431041_n.jpg
# Removed letterbox: Top=224px, Bottom=232px
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 366
#     363     print("The 'piexif' library is required to embed metadata. Install it using 'pip install piexif'.")
#     364     sys.exit(1)
# --> 366 main()
#
# Cell In[19], line 316, in main()
#     310 # if has_user_comment(image_path):
#     311 #     print("Image already has EXIF UserComment. Skipping.")
#     312 #     skipped_count += 1
#     313 #     continue
#     315 image_start_time = time.time()
# --> 316 success = process_image(image_path)
#     317 image_end_time = time.time()
#     319 if success:
#
# Cell In[19], line 229, in process_image(image_path)
#     227 # Skewness and Kurtosis of Luminance
#     228 lum_skew = skew(l_channel.flatten())
# --> 229 lum_kurt = kurtosis(l_channel.flatten())
#     231 # Compile Features
#     232 # additional_features = {
#     233 #     'Mean Luminance': f"{mean_luminance:.2f}",
#    (...)
#     258
#     259 # *** Combine All Metrics ***
#     260 all_metrics = {
#     261       'Mean Luminance': f"{mean_luminance:.2f}",
#     262     'Median Luminance': f"{median_luminance:.2f}",
#    (...)
#     280     }
#     281 }
#
# File ~/Projects/custom_gallery/myenv/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:573, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     570     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     571     return tuple_to_result(*res)
# --> 573 res = hypotest_fun_out(*samples, **kwds)
#     574 res = result_to_tuple(res)
#     575 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~/Projects/custom_gallery/myenv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1312, in kurtosis(a, axis, fisher, bias, nan_policy)
#    1310 mean = xp.mean(a, axis=axis, keepdims=True)
#    1311 mean_reduced = xp.squeeze(mean, axis=axis)  # needed later
# -> 1312 m2 = _moment(a, 2, axis, mean=mean, xp=xp)
#    1313 m4 = _moment(a, 4, axis, mean=mean, xp=xp)
#    1314 with np.errstate(all='ignore'):
#
# File ~/Projects/custom_gallery/myenv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1105, in _moment(a, order, axis, mean, xp)
#    1103     if n % 2:
#    1104         s *= a_zero_mean
# -> 1105 return xp.mean(s, axis=axis)
#
# File ~/Projects/custom_gallery/myenv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3778, in _mean_dispatcher(a, axis, dtype, out, keepdims, where)
#    3763     """
#    3764     Round an array to the given number of decimals.
#    3765
#    (...)
#    3773
#    3774     """
#    3775     return _wrapfunc(a, 'round', decimals=decimals, out=out)
# -> 3778 def _mean_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None, *,
#    3779                      where=None):
#    3780     return (a, where, out)
#    3783 @array_function_dispatch(_mean_dispatcher)
#    3784 def mean(a, axis=None, dtype=None, out=None, keepdims=np._NoValue, *,
#    3785          where=np._NoValue):
#
# KeyboardInterrupt:
